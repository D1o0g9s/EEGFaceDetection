# %%
from helperFunctions import *
from constants import *
import matplotlib.pyplot as plt

# %%
# Load XDF File

"""
Files that work
marker_only.xdf
sub-P001_ses-S001_task-T1_run-001_eeg.xdf
mindwave.xdf
part_P001_block_S001.xdf
"""

filename = "part_P001_block_S001"

XDF_Path = "./data/"+filename+".xdf"
XDF_Data = loadxdf(XDF_Path)

# %%
plt.plot(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,0], label="eeg")
plt.legend()
plt.show()

# %%
epochByMarkIndex(1, 2, XDF_Path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b1cc3d2f8546> in <module>
# ----> 1 epochByMarkIndex(1, 2, XDF_Path)
#
# ~\Git\EEGFaceDetection\Data_Analysis\helperFunctions.py in epochByMarkIndex(mrk_from_index, mrk_to_index, data)
#      78 def epochByMarkIndex(mrk_from_index, mrk_to_index, data):
#      79
# ---> 80     start_timestamp = getTimestampForMarkIndex(mrk_from_index, data)
#      81     end_timestamp = getTimestampForMarkIndex(mrk_to_index, data)
#      82
#
# ~\Git\EEGFaceDetection\Data_Analysis\helperFunctions.py in getTimestampForMarkIndex(mrk_index, data)
#      73 # Get the corresponding timestamp for a marker index
#      74 def getTimestampForMarkIndex(mrk_index, data):
# ---> 75     return data[StreamType.MARKER.value][StreamType.TIME.value][mrk_index]
#      76
#      77 # Return a new data structure that starts at the marker from index up to the marker to index (inclusive)
#
# TypeError: string indices must be integers
