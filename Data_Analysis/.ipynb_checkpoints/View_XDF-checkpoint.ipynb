# %%
from helperFunctions import *
from constants import *

# %%
# Load XDF File

"""
Files that work
part_P001_block_S001.xdf # This does not have the cross hair
part_P002_block_S001.xdf # These have cross hairs
part_P003_block_S001.xdf 

These experiments consist of the user looking at faces vs landscape as labeled by the Markers. 
In the more recent experiments, there are also cross hairs for the subject to fixate on before 
each new image is shown. 
"""
filename = "part_P002_block_S001"

XDF_Path = "./data/"+filename+".xdf"
XDF_Data = loadxdf(XDF_Path)

# %%
# Measures from NeuroSky [Raw EEG, Attention, Meditation, Blinks]
print(sum(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,3]), "blinks detected")
# Out:
# 0.0 blinks detected

# %%
XDF_Data
# Out:
# {'eeg': {'data': array([[ 41.51934 ,  59.558014, -48.37971 ,   0.      ],
#          [ 75.51934 ,  59.558014, -48.37971 ,   0.      ],
#          [ 58.51934 ,  59.558014, -48.37971 ,   0.      ],
#          ...,
#          [ 74.51934 ,  10.558014,  37.62029 ,   0.      ],
#          [ 74.51934 ,  10.558014,  37.62029 ,   0.      ],
#          [ 74.51934 ,  10.558014,  37.62029 ,   0.      ]], dtype=float32),
#   'time': array([6805.51464619, 6805.52439599, 6805.53315973, ..., 6859.49486514,
#          6859.50279629, 6859.51080091]),
#   'fs': '128'},
#  'markers': {'data': array([['RecordingStart'],
#          ['CalibrationStart'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Henry.png'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape1.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Colin.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape3.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Vikash.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape2.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Zeyun.png'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape1.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Geeling.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape3.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Kevin.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape2.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Henry.png'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape1.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Colin.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape3.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Vikash.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape2.jpg'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Face'],
#          ['./images/faces/Zeyun.png'],
#          ['NewImageEnd'],
#          ['CrossStart'],
#          ['CrossEnd'],
#          ['NewImageStart'],
#          ['Landscape'],
#          ['./images/landscape/landscape1.jpg'],
#          ['NewImageEnd'],
#          ['CalibrationEnd'],
#          ['RecordingEnd']], dtype='<U33'),
#   'time': array([6812.26432508, 6819.94954961, 6819.94959339, 6820.46480409,
#          6820.46481596, 6820.46482301, 6820.58066413, 6821.68251968,
#          6821.68254946, 6822.19849819, 6822.19850994, 6822.1985167 ,
#          6822.5706574 , 6823.68220027, 6823.68222963, 6824.19847553,
#          6824.1984877 , 6824.19849486, 6824.22270672, 6825.23274035,
#          6825.23276925, 6825.84941576, 6825.8494303 , 6825.84943987,
#          6825.91814743, 6826.93275874, 6826.93281077, 6827.54980256,
#          6827.5498148 , 6827.54982212, 6827.56057551, 6828.56634011,
#          6828.56636923, 6829.18351503, 6829.18352777, 6829.18353472,
#          6829.22202808, 6830.23326049, 6830.23328956, 6830.8506761 ,
#          6830.85068801, 6830.8506952 , 6830.88530451, 6832.0006193 ,
#          6832.00064812, 6832.6174072 , 6832.61741924, 6832.61742646,
#          6832.87031495, 6833.88498436, 6833.88501342, 6834.40068784,
#          6834.40070061, 6834.40070778, 6834.58767941, 6835.60075027,
#          6835.60077815, 6836.21807129, 6836.21808316, 6836.21809008,
#          6836.26565338, 6837.3679198 , 6837.36794809, 6837.98874369,
#          6837.98875647, 6837.98876415, 6838.0034397 , 6839.11800922,
#          6839.11803783, 6839.7351269 , 6839.73513935, 6839.73514629,
#          6839.76207847, 6840.76923596, 6840.76926409, 6841.38569479,
#          6841.38570652, 6841.38571382, 6841.42522512, 6842.54343586,
#          6842.54346351, 6843.15196303, 6843.15197547, 6843.15198253,
#          6843.39497843, 6844.40313711, 6844.40316807, 6845.02174372,
#          6845.02175948, 6845.02176879, 6845.03727017, 6846.0532088 ,
#          6846.05324541, 6846.55788773, 6846.55789992, 6846.55790669,
#          6846.60338967, 6847.61960345, 6847.61962566, 6848.12736779,
#          6848.12737967, 6848.12738711, 6848.13324555, 6849.13603016,
#          6849.1360584 , 6849.75471122, 6849.75472275, 6849.75472917,
#          6849.78006876, 6850.88646551, 6850.88649409, 6851.50343436,
#          6851.50344582, 6851.50345301, 6851.52181328, 6852.63668728,
#          6852.63671619, 6853.14349201, 6853.14350353, 6853.14351046,
#          6853.37028005, 6854.37120445, 6854.37121983, 6854.37122758])}}

# %%
plt.plot(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,0], label="eeg")
plt.legend()
plt.show()

# %%
plt.plot(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,1], label="attention")
plt.plot(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,2], label="meditation")
plt.plot(XDF_Data[StreamType.EEG.value][StreamType.DATA.value][:,3], label="blink")
plt.legend()
plt.show()

# %%
# Show marker data
XDF_Data[StreamType.MARKER.value][StreamType.DATA.value]
# Out:
# array([['RecordingStart'],
#        ['CalibrationStart'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Henry.png'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape1.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Colin.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape3.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Vikash.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape2.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Zeyun.png'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape1.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Geeling.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape3.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Kevin.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape2.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Henry.png'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape1.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Colin.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape3.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Vikash.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape2.jpg'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Face'],
#        ['./images/faces/Zeyun.png'],
#        ['NewImageEnd'],
#        ['CrossStart'],
#        ['CrossEnd'],
#        ['NewImageStart'],
#        ['Landscape'],
#        ['./images/landscape/landscape1.jpg'],
#        ['NewImageEnd'],
#        ['CalibrationEnd'],
#        ['RecordingEnd']], dtype='<U33')

# %%
first_trial = getMarkerBoundSingleMarkerData('NewImageStart', 'NewImageEnd', XDF_Data, go_backward=False)
